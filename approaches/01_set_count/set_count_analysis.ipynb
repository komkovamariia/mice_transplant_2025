# %% [markdown]
# # Approach 1: Exact clonotype sets and differential counts
#
# This notebook quantifies exact aaV set membership and differential abundance for g1 versus the allogeneic g5+g6 reference. edgeR provides the primary sample-resolved model; Fisher's exact test is retained as an independent count-based check.
#
# The four cell-by-compartment strata are analyzed independently. The two combined strata pool thymus and spleen counts within each mouse before testing. Every table, figure, and result-specific conclusion is saved under the approach-specific output directories.

# %%
from src.runtime import configure_runtime

N_WORKERS = configure_runtime()

from src.approach1_set_count import compile_summary, run_stratum
from src.strata import load_repertoire, requested_strata, validate_strata

repertoire = load_repertoire()
STRATA = requested_strata()
display(validate_strata(repertoire, STRATA))

# %%
if "cd4_thymus" in STRATA:
    result_cd4_thymus = run_stratum(repertoire, "cd4_thymus")
    display(result_cd4_thymus)

# %%
if "cd4_spleen" in STRATA:
    result_cd4_spleen = run_stratum(repertoire, "cd4_spleen")
    display(result_cd4_spleen)

# %%
if "cd8_thymus" in STRATA:
    result_cd8_thymus = run_stratum(repertoire, "cd8_thymus")
    display(result_cd8_thymus)

# %%
if "cd8_spleen" in STRATA:
    result_cd8_spleen = run_stratum(repertoire, "cd8_spleen")
    display(result_cd8_spleen)

# %%
if "cd4_combined" in STRATA:
    result_cd4_combined = run_stratum(repertoire, "cd4_combined")
    display(result_cd4_combined)

# %%
if "cd8_combined" in STRATA:
    result_cd8_combined = run_stratum(repertoire, "cd8_combined")
    display(result_cd8_combined)

# %%
summary = compile_summary(STRATA)
display(summary)

# %% [markdown]
# ## Interpretation
#
# Each stratum writes a dedicated Markdown conclusion beside its statistical tables. Interpretation should prioritize effect direction, false-discovery control, and reproducibility across strata and methods.

# %% [markdown]
# # Approach 2: Sequence-space enrichment and repertoire geometry
#
# A single TCREmp/PCA basis provides a shared technical coordinate system. Each biological stratum is then tested independently with exact k-d-tree density enrichment, RFF-MMD geometry, two-group deterministic PERMANOVA, and witness scoring.
#
# For the combined strata, thymus and spleen are pooled within each mouse before repertoire-level analysis. Every figure is saved as PNG and PDF under `figures/02_sequence_embedding/<stratum>/`.

# %%
from src.runtime import configure_runtime

N_WORKERS = configure_runtime()

from src.approach2_sequence_embedding import (
    compile_summary,
    prepare_embedding,
    run_stratum,
)
from src.strata import load_repertoire, requested_strata, validate_strata

repertoire = load_repertoire()
STRATA = requested_strata()
display(validate_strata(repertoire, STRATA))

# %%
context = prepare_embedding(repertoire, seed=0)
print(
    f"Shared sequence-space basis: {context['coordinates'].shape[0]:,} clonotypes x {context['coordinates'].shape[1]} dimensions"
)

# %%
if "cd4_thymus" in STRATA:
    result_cd4_thymus = run_stratum(context, "cd4_thymus")
    display(result_cd4_thymus)

# %%
if "cd4_spleen" in STRATA:
    result_cd4_spleen = run_stratum(context, "cd4_spleen")
    display(result_cd4_spleen)

# %%
if "cd8_thymus" in STRATA:
    result_cd8_thymus = run_stratum(context, "cd8_thymus")
    display(result_cd8_thymus)

# %%
if "cd8_spleen" in STRATA:
    result_cd8_spleen = run_stratum(context, "cd8_spleen")
    display(result_cd8_spleen)

# %%
if "cd4_combined" in STRATA:
    result_cd4_combined = run_stratum(context, "cd4_combined")
    display(result_cd4_combined)

# %%
if "cd8_combined" in STRATA:
    result_cd8_combined = run_stratum(context, "cd8_combined")
    display(result_cd8_combined)

# %%
summary = compile_summary(STRATA)
display(summary)

# %% [markdown]
# ## Interpretation
#
# Density, repertoire geometry, and witness scores describe complementary scales of the same contrast. Each stratum writes a result-specific conclusion; none of these statistics alone establishes antigen specificity.

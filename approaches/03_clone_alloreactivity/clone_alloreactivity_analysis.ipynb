# %% [markdown]
# # Approach 3: Clone-level alloreactivity prioritization
#
# This notebook ranks individual aaV clonotypes using sample-resolved evidence that is independent of the sequence-density test: allogeneic mouse prevalence, allogeneic-to-g1 abundance shift, and local CDR3 convergence within the same V segment. Sequence physicochemical descriptors are retained for interpretation but are not treated as evidence of antigen specificity.
#
# Each biological stratum is evaluated independently. Candidate and V-segment tables are written to `outputs/tables/03_clone_alloreactivity/`; figures are saved under `figures/03_clone_alloreactivity/<stratum>/`.

# %%
from src.runtime import configure_runtime
N_WORKERS = configure_runtime()

from src.strata import load_repertoire, requested_strata, validate_strata
from src.approach3_clone_alloreactivity import run_stratum, compile_summary

repertoire = load_repertoire()
STRATA = requested_strata()
display(validate_strata(repertoire).query("stratum in @STRATA"))

# %%
if "cd4_thymus" in STRATA:
    result_cd4_thymus = run_stratum(repertoire, "cd4_thymus")
    display(result_cd4_thymus)

# %%
if "cd4_spleen" in STRATA:
    result_cd4_spleen = run_stratum(repertoire, "cd4_spleen")
    display(result_cd4_spleen)

# %%
if "cd8_thymus" in STRATA:
    result_cd8_thymus = run_stratum(repertoire, "cd8_thymus")
    display(result_cd8_thymus)

# %%
if "cd8_spleen" in STRATA:
    result_cd8_spleen = run_stratum(repertoire, "cd8_spleen")
    display(result_cd8_spleen)

# %%
if "cd4_combined" in STRATA:
    result_cd4_combined = run_stratum(repertoire, "cd4_combined")
    display(result_cd4_combined)

# %%
if "cd8_combined" in STRATA:
    result_cd8_combined = run_stratum(repertoire, "cd8_combined")
    display(result_cd8_combined)

# %%
summary = compile_summary(STRATA)
display(summary)

# %% [markdown]
# ## Interpretation
#
# The integrated score is a prioritization statistic, not a probability of alloreactivity. Strong candidates are those repeatedly observed in allogeneic mice, shifted away from g1, and supported by local sequence convergence. Cross-approach agreement is evaluated separately in Approach 4.

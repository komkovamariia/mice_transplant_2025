# %% [markdown]
# # Cross-approach comparison
#
# This notebook integrates V-segment rankings from the three independent analytical lines. Comparisons are performed separately for each biological stratum using pairwise Spearman rank correlation, top-10 overlap, and a consensus rank based on normalized within-approach ranks.
#
# No upstream statistics are recomputed here. The notebook fails explicitly if any required stratum-level result is missing.

# %%
from src.runtime import configure_runtime
N_WORKERS = configure_runtime()

from src.strata import requested_strata
from src.approach4_cross_approach import run_stratum, compile_summary

STRATA = requested_strata()
print("Cross-approach strata:", ", ".join(STRATA))

# %%
if "cd4_thymus" in STRATA:
    result_cd4_thymus = run_stratum("cd4_thymus")
    display(result_cd4_thymus)

# %%
if "cd4_spleen" in STRATA:
    result_cd4_spleen = run_stratum("cd4_spleen")
    display(result_cd4_spleen)

# %%
if "cd8_thymus" in STRATA:
    result_cd8_thymus = run_stratum("cd8_thymus")
    display(result_cd8_thymus)

# %%
if "cd8_spleen" in STRATA:
    result_cd8_spleen = run_stratum("cd8_spleen")
    display(result_cd8_spleen)

# %%
if "cd4_combined" in STRATA:
    result_cd4_combined = run_stratum("cd4_combined")
    display(result_cd4_combined)

# %%
if "cd8_combined" in STRATA:
    result_cd8_combined = run_stratum("cd8_combined")
    display(result_cd8_combined)

# %%
summary = compile_summary(STRATA)
display(summary)

# %% [markdown]
# ## Interpretation
#
# A V segment is considered methodologically robust when it ranks highly across multiple analytical lines and does so in more than one biological stratum. Disagreement is retained as a result rather than forced into a consensus.

# %% [markdown]
# # Approach 1: exact clonotype sets and differential counts
#
# This notebook reproduces the verified first-pass input route from the metadata CSV, clonoset-index CSV, and referenced MiXCR exports. Exact functional TRA clonotypes are defined by CDR3 amino-acid sequence and TRAV segment (aaV). Each of eight biological strata is analyzed independently with set subtraction, edgeR quasi-likelihood inference, and a Fisher exact-test cross-check. No minimum UMI or read-count threshold is applied. All figures are written to the single repository-level `figures/01_set_count/` tree as PNG and PDF files.

# %%
from src.runtime import configure_runtime

N_WORKERS = configure_runtime()

from src.approach1_set_count import compile_summary, run_stratum
from src.figures import write_figure_inventory
from src.first_pass_input import first_pass_paths, load_first_pass_repertoire
from src.strata import requested_strata, validate_strata

metadata_path, clonoset_index_path = first_pass_paths()
print(f"Metadata: {metadata_path}")
print(f"Clonoset index: {clonoset_index_path}")
repertoire = load_first_pass_repertoire()
STRATA = requested_strata()
print(f"Workers available: {N_WORKERS}")
display(validate_strata(repertoire, STRATA))

# %% [markdown]
# ## 1. CD4 T cells: thymus
#
# Independent analysis unit: one CD4 thymus sample. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd4_thymus" in STRATA:
    result_cd4_thymus = lambda stratum: run_stratum(repertoire, stratum)("cd4_thymus")
    display(result_cd4_thymus)

# %% [markdown]
# ## 2. CD8 T cells: thymus
#
# Independent analysis unit: one CD8 thymus sample. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd8_thymus" in STRATA:
    result_cd8_thymus = lambda stratum: run_stratum(repertoire, stratum)("cd8_thymus")
    display(result_cd8_thymus)

# %% [markdown]
# ## 3. CD4 T cells: spleen
#
# Independent analysis unit: one CD4 spleen sample. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd4_spleen" in STRATA:
    result_cd4_spleen = lambda stratum: run_stratum(repertoire, stratum)("cd4_spleen")
    display(result_cd4_spleen)

# %% [markdown]
# ## 4. CD8 T cells: spleen
#
# Independent analysis unit: one CD8 spleen sample. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd8_spleen" in STRATA:
    result_cd8_spleen = lambda stratum: run_stratum(repertoire, stratum)("cd8_spleen")
    display(result_cd8_spleen)

# %% [markdown]
# ## 5. CD4 T cells: thymus and spleen
#
# Independent analysis unit: CD4 thymus and spleen counts pooled within mouse. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd4_combined" in STRATA:
    result_cd4_combined = lambda stratum: run_stratum(repertoire, stratum)("cd4_combined")
    display(result_cd4_combined)

# %% [markdown]
# ## 6. CD8 T cells: thymus and spleen
#
# Independent analysis unit: CD8 thymus and spleen counts pooled within mouse. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "cd8_combined" in STRATA:
    result_cd8_combined = lambda stratum: run_stratum(repertoire, stratum)("cd8_combined")
    display(result_cd8_combined)

# %% [markdown]
# ## 7. Thymus: CD4 and CD8 T cells
#
# Independent analysis unit: CD4 and CD8 thymus counts pooled within mouse. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "thymus_combined" in STRATA:
    result_thymus_combined = lambda stratum: run_stratum(repertoire, stratum)("thymus_combined")
    display(result_thymus_combined)

# %% [markdown]
# ## 8. Spleen: CD4 and CD8 T cells
#
# Independent analysis unit: CD4 and CD8 spleen counts pooled within mouse. The g1 repertoire is compared with the pooled g5+g6 allogeneic reference.

# %%
if "spleen_combined" in STRATA:
    result_spleen_combined = lambda stratum: run_stratum(repertoire, stratum)("spleen_combined")
    display(result_spleen_combined)

# %% [markdown]
# ## Consolidated TRAV results
#
# The final table retains the evidence class, effect direction, rank, and recurrence of every distinctive TRAV segment across all completed strata.

# %%
summary = compile_summary(STRATA)
display(summary)
inventory = write_figure_inventory()
print(f"Figure inventory: {inventory}")

# %% [markdown]
# ## Interpretation
#
# Use each stratum-specific Markdown conclusion for biological interpretation. Use `results/01_set_count/distinctive_trav_summary.csv` to compare TRAV signals across the eight strata. Positive signed effects indicate enrichment in g1; negative effects indicate enrichment in the g5+g6 reference.
